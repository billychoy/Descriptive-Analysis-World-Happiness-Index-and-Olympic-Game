# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#import olympic data
athletes = pd.read_csv("athletes.csv")
countries = pd.read_csv("countries.csv")
events = pd.read_csv("events.csv", sep=',', engine='python')

# %%
athletes.head()
# Out:
#           id            name nationality     sex       dob  height  weight  \
# 0  736041664  A Jesus Garcia         ESP    male  10/17/69    1.72    64.0
# 1  532037425      A Lam Shin         KOR  female   9/23/86    1.68    56.0
# 2  435962603     Aaron Brown         CAN    male   5/27/92    1.98    79.0
# 3  521041435      Aaron Cook         MDA    male    1/2/91    1.83    80.0
# 4   33922579      Aaron Gate         NZL    male  11/26/90    1.81    71.0
#
#        sport  gold  silver  bronze
# 0  athletics     0       0       0
# 1    fencing     0       0       0
# 2  athletics     0       0       1
# 3  taekwondo     0       0       0
# 4    cycling     0       0       0

# %%
countries.head()
# Out:
#            country code  population  gdp_per_capita
# 0      Afghanistan  AFG  32526562.0      594.323081
# 1          Albania  ALB   2889167.0     3945.217582
# 2          Algeria  ALG  39666519.0     4206.031232
# 3  American Samoa*  ASA     55538.0             NaN
# 4          Andorra  AND     70473.0             NaN

# %%
events.head()
# Out:
#        id     sport    discipline                       name     sex  \
# 0  701492  aquatics    backstroke    Women's 100m Backstroke  female
# 1  305278  aquatics    backstroke    Women's 200m Backstroke  female
# 2  708010  aquatics    backstroke      Men's 100m Backstroke    male
# 3  729643  aquatics    backstroke      Men's 200m Backstroke    male
# 4  567019  aquatics  breaststroke  Women's 100m Breaststroke  female
#
#                      venues
# 0  Olympic Aquatics Stadium
# 1  Olympic Aquatics Stadium
# 2  Olympic Aquatics Stadium
# 3  Olympic Aquatics Stadium
# 4  Olympic Aquatics Stadium

# %%
#import World Happiness Report data
happy_2016 = pd.read_csv("Happiness_2016.csv")
happy_2017 = pd.read_csv("Happiness_2017.csv")

# %%
happy_2016.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0      Denmark  Western Europe               1            7.526
# 1  Switzerland  Western Europe               2            7.509
# 2      Iceland  Western Europe               3            7.501
# 3       Norway  Western Europe               4            7.498
# 4      Finland  Western Europe               5            7.413
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# 1                      7.428                      7.590
# 2                      7.333                      7.669
# 3                      7.421                      7.575
# 4                      7.351                      7.475
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                   1.44178  1.16374                   0.79504  0.57941
# 1                   1.52733  1.14524                   0.86303  0.58557
# ...

# %%
happy_2017.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
#start data cleansing on happy_2016 and happy_2017
#compare column names
happy_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
happy_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
#rename happy_2016 column names
happy_2016 = happy_2016.rename(columns={'Happiness Rank': 'Happiness_Rank', 'Happiness Score': 'Happiness_Score', 'Lower Confidence Interval': 'Lower_Confidence_Interval', 'Upper Confidence Interval': 'Upper_Confidence_Interval','Economy (GDP per Capita)': 'Economy_GDP_per_Capita', 'Health (Life Expectancy)': 'Health_Life Expectancy', 'Trust (Government Corruption)': 'Trust_Government_Corruption', 'Dystopia Residual': 'Dystopia_Residual'})

# %%
#double check result
happy_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness_Rank', 'Happiness_Score',
#        'Lower_Confidence_Interval', 'Upper_Confidence_Interval',
#        'Economy_GDP_per_Capita', 'Family', 'Health_Life Expectancy', 'Freedom',
#        'Trust_Government_Corruption', 'Generosity', 'Dystopia_Residual'],
#       dtype='object')

# %%
#rename happy_2017 column names
happy_2017 = happy_2017.rename(columns={'Happiness.Rank': 'Happiness_Rank', 'Happiness.Score': 'Happiness_Score', 'Whisker.low': 'Lower_Confidence_Interval', 'Whisker.high': 'Upper_Confidence_Interval','Economy..GDP.per.Capita.': 'Economy_GDP_per_Capita', 'Health..Life.Expectancy.': 'Health_Life Expectancy', 'Trust..Government.Corruption.': 'Trust_Government_Corruption', 'Dystopia.Residual': 'Dystopia_Residual'})

# %%
#double check result
happy_2017.columns
# Out:
# Index(['Country', 'Happiness_Rank', 'Happiness_Score',
#        'Upper_Confidence_Interval', 'Lower_Confidence_Interval',
#        'Economy_GDP_per_Capita', 'Family', 'Health_Life Expectancy', 'Freedom',
#        'Generosity', 'Trust_Government_Corruption', 'Dystopia_Residual'],
#       dtype='object')

# %%
happy_compare = pd.merge(happy_2016, happy_2017, how='outer', on='Country', suffixes=('_2016', '_2017'))

# %%
happy_compare
# Out:
#                       Country          Region  Happiness_Rank_2016  \
# 0                     Denmark  Western Europe                  1.0
# 1                 Switzerland  Western Europe                  2.0
# 2                     Iceland  Western Europe                  3.0
# 3                      Norway  Western Europe                  4.0
# 4                     Finland  Western Europe                  5.0
# ..                        ...             ...                  ...
# 157  Taiwan Province of China             NaN                  NaN
# 158   Hong Kong S.A.R., China             NaN                  NaN
# 159                Mozambique             NaN                  NaN
# 160                   Lesotho             NaN                  NaN
# 161  Central African Republic             NaN                  NaN
#
#      Happiness_Score_2016  Lower_Confidence_Interval_2016  \
# 0                   7.526                           7.460
# ...

# %%
#find out the number of unmatch 2016 vs 2017
happy_compare['Happiness_Rank_2016'].isna().sum()
# Out:
# 5

# %%
#list out the unmatch 2016 vs 2017
happy_compare[happy_compare['Happiness_Rank_2016'].isna()]
# Out:
#                       Country Region  Happiness_Rank_2016  \
# 157  Taiwan Province of China    NaN                  NaN
# 158   Hong Kong S.A.R., China    NaN                  NaN
# 159                Mozambique    NaN                  NaN
# 160                   Lesotho    NaN                  NaN
# 161  Central African Republic    NaN                  NaN
#
#      Happiness_Score_2016  Lower_Confidence_Interval_2016  \
# 157                   NaN                             NaN
# 158                   NaN                             NaN
# 159                   NaN                             NaN
# 160                   NaN                             NaN
# 161                   NaN                             NaN
#
#      Upper_Confidence_Interval_2016  Economy_GDP_per_Capita_2016  Family_2016  \
# 157                             NaN                          NaN          NaN
# 158                             NaN                          NaN          NaN
# ...

# %%
#find out the number of unmatch 2017 vs 2016
happy_compare['Happiness_Rank_2017'].isna().sum()
# Out:
# 7

# %%
#list out the unmatch 2017 vs 2016
happy_compare[happy_compare['Happiness_Rank_2017'].isna()]
# Out:
#                Country                       Region  Happiness_Rank_2016  \
# 14         Puerto Rico  Latin America and Caribbean                 15.0
# 34              Taiwan                 Eastern Asia                 34.0
# 39            Suriname  Latin America and Caribbean                 40.0
# 74           Hong Kong                 Eastern Asia                 75.0
# 96   Somaliland Region           Sub-Saharan Africa                 97.0
# 101               Laos            Southeastern Asia                102.0
# 137            Comoros           Sub-Saharan Africa                138.0
#
#      Happiness_Score_2016  Lower_Confidence_Interval_2016  \
# 14                  7.039                           6.794
# 34                  6.379                           6.305
# 39                  6.269                           6.073
# 74                  5.458                           5.362
# 96                  5.057                           4.934
# ...

# %%
#match 2016 & 2017
happy_2017['Country'][happy_2017['Country'] == 'Taiwan Province of China']  = 'Taiwan'
happy_2017['Country'][happy_2017['Country'] == 'Hong Kong S.A.R., China']  = 'Hong Kong'
# Out:
# <ipython-input-40-284dc0933c69>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   happy_2017['Country'][happy_2017['Country'] == 'Taiwan Province of China']  = 'Taiwan'
# <ipython-input-40-284dc0933c69>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   happy_2017['Country'][happy_2017['Country'] == 'Hong Kong S.A.R., China']  = 'Hong Kong'

# %%
#check the result
happy_compare_clean = pd.merge(happy_2016, happy_2017, how='outer', on='Country', suffixes=('_2016', '_2017'))

# %%
happy_compare_clean['Happiness_Rank_2017'].isna().sum()
# Out:
# 5

# %%
happy_compare_clean[happy_compare_clean['Happiness_Rank_2016'].isna()|happy_compare_clean['Happiness_Rank_2017'].isna()]
# Out:
#                       Country                       Region  \
# 14                Puerto Rico  Latin America and Caribbean
# 39                   Suriname  Latin America and Caribbean
# 96          Somaliland Region           Sub-Saharan Africa
# 101                      Laos            Southeastern Asia
# 137                   Comoros           Sub-Saharan Africa
# 157                Mozambique                          NaN
# 158                   Lesotho                          NaN
# 159  Central African Republic                          NaN
#
#      Happiness_Rank_2016  Happiness_Score_2016  \
# 14                  15.0                 7.039
# 39                  40.0                 6.269
# 96                  97.0                 5.057
# 101                102.0                 4.876
# 137                138.0                 3.956
# 157                  NaN                   NaN
# 158                  NaN                   NaN
# 159                  NaN                   NaN
#
# ...

# %%
#start data cleansing on olympic data
#calculate total medals per nationality
athletes1 = athletes[["nationality","gold","silver","bronze"]]
medals = athletes1.groupby(by='nationality', axis=0, as_index=False).sum()

# %%
#add medals total
medals['total_medals'] = medals['gold'] + medals['silver'] + medals['bronze']

# %%
medals.head()
# Out:
#   nationality  gold  silver  bronze  total_medals
# 0         AFG     0       0       0             0
# 1         ALB     0       0       0             0
# 2         ALG     0       2       0             2
# 3         AND     0       0       0             0
# 4         ANG     0       0       0             0

# %%
#merge medals and countries

# %%
olympic = pd.merge(medals, countries, how='left', left_on='nationality', right_on='code')

# %%
olympic.head()
# Out:
#   nationality  gold  silver  bronze  total_medals      country code  \
# 0         AFG     0       0       0             0  Afghanistan  AFG
# 1         ALB     0       0       0             0      Albania  ALB
# 2         ALG     0       2       0             2      Algeria  ALG
# 3         AND     0       0       0             0      Andorra  AND
# 4         ANG     0       0       0             0       Angola  ANG
#
#    population  gdp_per_capita
# 0  32526562.0      594.323081
# 1   2889167.0     3945.217582
# 2  39666519.0     4206.031232
# 3     70473.0             NaN
# 4  25021974.0     4101.472152

# %%
#data cleansing - find out if there is nay unmatch nationality and country
olympic['country'].isna().sum()
# Out:
# 11

# %%
olympic[olympic['country'].isna()]
# Out:
#     nationality  gold  silver  bronze  total_medals country code  population  \
# 86          IOA     1       0       1             2     NaN  NaN         NaN
# 101         KIR     0       0       0             0     NaN  NaN         NaN
# 103         KOS     1       0       0             1     NaN  NaN         NaN
# 123         MHL     0       0       0             0     NaN  NaN         NaN
# 127         MNE     0       0       0             0     NaN  NaN         NaN
# 156         ROT     0       0       0             0     NaN  NaN         NaN
# 157         ROU     4       2      11            17     NaN  NaN         NaN
# 171         SRB    14      26      13            53     NaN  NaN         NaN
# 173         SSD     0       0       0             0     NaN  NaN         NaN
# 190         TTO     0       0       1             1     NaN  NaN         NaN
# 193         TUV     0       0       0             0     NaN  NaN         NaN
#
#      gdp_per_capita
# 86              NaN
# ...

# %%
olympic['country'][olympic['nationality'] == 'IOA']  = 'Independent Olympic Athletes'
olympic['country'][olympic['nationality'] == 'KIR']  = 'Kiribati'
olympic['country'][olympic['nationality'] == 'KOS']  = 'Kosovo'
olympic['country'][olympic['nationality'] == 'MHL']  = 'Marshall Islands'
olympic['country'][olympic['nationality'] == 'MNE']  = 'Montenegro'
olympic['country'][olympic['nationality'] == 'ROT']  = 'Refugee Olympic Team'
olympic['country'][olympic['nationality'] == 'ROU']  = 'Romania'
olympic['country'][olympic['nationality'] == 'SRB']  = 'Serbia'
olympic['country'][olympic['nationality'] == 'SSD']  = 'South Sudan'
olympic['country'][olympic['nationality'] == 'TTO']  = 'Trinidad and Tobago'
olympic['country'][olympic['nationality'] == 'TUV']  = 'Tuvalu'
# Out:
# <ipython-input-53-1085ffbe508d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic['country'][olympic['nationality'] == 'IOA']  = 'Independent Olympic Athletes'
# <ipython-input-53-1085ffbe508d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic['country'][olympic['nationality'] == 'KIR']  = 'Kiribati'
# <ipython-input-53-1085ffbe508d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#double check the update of nationality
olympic[olympic['nationality'] == 'IOA']
# Out:
#    nationality  gold  silver  bronze  total_medals  \
# 86         IOA     1       0       1             2
#
#                          country code  population  gdp_per_capita
# 86  Independent Olympic Athletes  NaN         NaN             NaN

# %%
olympic[olympic['nationality'] == 'KIR']
# Out:
#     nationality  gold  silver  bronze  total_medals   country code  \
# 101         KIR     0       0       0             0  Kiribati  NaN
#
#      population  gdp_per_capita
# 101         NaN             NaN

# %%
olympic[olympic['nationality'] == 'KOS']
# Out:
#     nationality  gold  silver  bronze  total_medals country code  population  \
# 103         KOS     1       0       0             1  Kosovo  NaN         NaN
#
#      gdp_per_capita
# 103             NaN

# %%
olympic[olympic['nationality'] == 'MHL']
# Out:
#     nationality  gold  silver  bronze  total_medals           country code  \
# 123         MHL     0       0       0             0  Marshall Islands  NaN
#
#      population  gdp_per_capita
# 123         NaN             NaN

# %%
olympic[olympic['nationality'] == 'MNE']
# Out:
#     nationality  gold  silver  bronze  total_medals     country code  \
# 127         MNE     0       0       0             0  Montenegro  NaN
#
#      population  gdp_per_capita
# 127         NaN             NaN

# %%
olympic[olympic['nationality'] == 'ROT']
# Out:
#     nationality  gold  silver  bronze  total_medals               country  \
# 156         ROT     0       0       0             0  Refugee Olympic Team
#
#     code  population  gdp_per_capita
# 156  NaN         NaN             NaN

# %%
olympic[olympic['nationality'] == 'ROU']
# Out:
#     nationality  gold  silver  bronze  total_medals  country code  population  \
# 157         ROU     4       2      11            17  Romania  NaN         NaN
#
#      gdp_per_capita
# 157             NaN

# %%
olympic[olympic['nationality'] == 'SRB']
# Out:
#     nationality  gold  silver  bronze  total_medals country code  population  \
# 171         SRB    14      26      13            53  Serbia  NaN         NaN
#
#      gdp_per_capita
# 171             NaN

# %%
olympic[olympic['nationality'] == 'SSD']
# Out:
#     nationality  gold  silver  bronze  total_medals      country code  \
# 173         SSD     0       0       0             0  South Sudan  NaN
#
#      population  gdp_per_capita
# 173         NaN             NaN

# %%
olympic[olympic['nationality'] == 'TTO']
# Out:
#     nationality  gold  silver  bronze  total_medals              country code  \
# 190         TTO     0       0       1             1  Trinidad and Tobago  NaN
#
#      population  gdp_per_capita
# 190         NaN             NaN

# %%
olympic[olympic['nationality'] == 'TUV']
# Out:
#     nationality  gold  silver  bronze  total_medals country code  population  \
# 193         TUV     0       0       0             0  Tuvalu  NaN         NaN
#
#      gdp_per_capita
# 193             NaN

# %%
olympic.head()
# Out:
#   nationality  gold  silver  bronze  total_medals      country code  \
# 0         AFG     0       0       0             0  Afghanistan  AFG
# 1         ALB     0       0       0             0      Albania  ALB
# 2         ALG     0       2       0             2      Algeria  ALG
# 3         AND     0       0       0             0      Andorra  AND
# 4         ANG     0       0       0             0       Angola  ANG
#
#    population  gdp_per_capita
# 0  32526562.0      594.323081
# 1   2889167.0     3945.217582
# 2  39666519.0     4206.031232
# 3     70473.0             NaN
# 4  25021974.0     4101.472152

# %%
#merge olypmpic+happy2016
olympic_happy2016 = pd.merge(olympic, happy_2016, how='left', left_on='country', right_on='Country')

# %%
olympic_happy2016.head()
# Out:
#   nationality  gold  silver  bronze  total_medals      country code  \
# 0         AFG     0       0       0             0  Afghanistan  AFG
# 1         ALB     0       0       0             0      Albania  ALB
# 2         ALG     0       2       0             2      Algeria  ALG
# 3         AND     0       0       0             0      Andorra  AND
# 4         ANG     0       0       0             0       Angola  ANG
#
#    population  gdp_per_capita      Country  ... Happiness_Score  \
# 0  32526562.0      594.323081  Afghanistan  ...           3.360
# 1   2889167.0     3945.217582      Albania  ...           4.655
# 2  39666519.0     4206.031232      Algeria  ...           6.355
# 3     70473.0             NaN          NaN  ...             NaN
# 4  25021974.0     4101.472152       Angola  ...           3.866
#
#    Lower_Confidence_Interval  Upper_Confidence_Interval  \
# 0                      3.288                      3.432
# ...

# %%
olympic_happy2016['Country'].isna().sum()
# Out:
# 61

# %%
olympic_happy2016[olympic_happy2016['Country'].isna()]
# Out:
#     nationality  gold  silver  bronze  total_medals  \
# 3           AND     0       0       0             0
# 5           ANT     0       0       0             0
# 8           ARU     0       0       0             0
# 9           ASA     0       0       0             0
# 13          BAH     1       0       5             6
# ..          ...   ...     ...     ...           ...
# 183         TGA     0       0       0             0
# 187         TLS     0       0       0             0
# 193         TUV     0       0       0             0
# 200         VAN     0       0       0             0
# 203         VIN     0       0       0             0
#
#                               country code  population  gdp_per_capita  \
# 3                             Andorra  AND     70473.0             NaN
# 5                 Antigua and Barbuda  ANT     91818.0    13714.731962
# 8                              Aruba*  ARU    103889.0             NaN
# ...

# %%
#show all rows and columns
pd.options.display.max_rows = 200
pd.set_option('display.max_columns', 500)
#list out unmatch data
olympic_happy2016[olympic_happy2016['Country'].isna()]
# Out:
#     nationality  gold  silver  bronze  total_medals  \
# 3           AND     0       0       0             0
# 5           ANT     0       0       0             0
# 8           ARU     0       0       0             0
# 9           ASA     0       0       0             0
# 13          BAH     1       0       5             6
# 15          BAR     0       0       0             0
# 19          BER     0       0       0             0
# 28          BRU     0       0       0             0
# 31          CAF     0       0       0             0
# 34          CAY     0       0       0             0
# 35          CGO     0       0       0             0
# 39          CIV     1       0       1             2
# 41          COD     0       0       0             0
# 42          COK     0       0       0             0
# 45          CPV     0       0       0             0
# 48          CUB     5       2       4            11
# 52          DJI     0       0       0             0
# ...

# %%
#Unmatch data to solve
#'Congo' in olympic Congo(Brazzaville) in happiness_2016
#'Congo, Dem Rep' in olympic vs Congo(Kinshasa) in happiness_2016
#Hong Kong* in olympic vs Hong Kong in happiness_2016
#Puerto Rico* in olympic vs Puerto Rico in happiness_2016
#Korea, South in olympic vs South Korea in happiness_2016

# %%
#data cleansing on olympic fix 'Congo' & 'Congo, Dem Rep'
olympic['country'][olympic['country'] == 'Congo']  = 'Congo (Brazzaville)'
olympic['country'][olympic['country'] == 'Congo, Dem Rep']  = 'Congo (Kinshasa)'
# Out:
# <ipython-input-72-30c6679bc45a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic['country'][olympic['country'] == 'Congo']  = 'Congo (Brazzaville)'
# <ipython-input-72-30c6679bc45a>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic['country'][olympic['country'] == 'Congo, Dem Rep']  = 'Congo (Kinshasa)'

# %%
#data check
olympic[olympic['country'] == 'Congo (Brazzaville)']
# Out:
#    nationality  gold  silver  bronze  total_medals              country code  \
# 35         CGO     0       0       0             0  Congo (Brazzaville)  CGO
#
#     population  gdp_per_capita
# 35   4620330.0     1851.199916

# %%
olympic[olympic['country'] == 'Congo (Kinshasa)']
# Out:
#    nationality  gold  silver  bronze  total_medals           country code  \
# 41         COD     0       0       0             0  Congo (Kinshasa)  COD
#
#     population  gdp_per_capita
# 41  77266814.0      456.052741

# %%
#data cleansing on olympic remove '*' 
#solve problems of #Hong Kong* in olympic vs Hong Kong in happiness_2016 & #Puerto Rico* in olympic vs Puerto Rico in happiness_2016
olympic['country'] = olympic['country'].str.rstrip('*')

# %%
#data check
olympic[olympic['country'] == 'Hong Kong']
# Out:
#    nationality  gold  silver  bronze  total_medals    country code  \
# 81         HKG     0       0       0             0  Hong Kong  HKG
#
#     population  gdp_per_capita
# 81   7305700.0    42327.839957

# %%
olympic[olympic['country'] == 'Puerto Rico']
# Out:
#     nationality  gold  silver  bronze  total_medals      country code  \
# 154         PUR     1       0       0             1  Puerto Rico  PUR
#
#      population  gdp_per_capita
# 154   3474182.0             NaN

# %%
#data cleansing on Korea, South in olympic vs South Korea in happiness_2016
olympic['country'][olympic['country'] == 'Korea, South']  = 'South Korea'
# Out:
# <ipython-input-78-b66c804f2474>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   olympic['country'][olympic['country'] == 'Korea, South']  = 'South Korea'

# %%
olympic[olympic['country'] == 'South Korea']
# Out:
#     nationality  gold  silver  bronze  total_medals      country code  \
# 102         KOR    13       3      10            26  South Korea  KOR
#
#      population  gdp_per_capita
# 102  50617045.0    27221.524051

# %%
#merge the data again
olympic_happy2016 = pd.merge(olympic, happy_2016, how='left', left_on='country', right_on='Country')

# %%
#check unmatch data again
olympic_happy2016['Country'].isna().sum()
# Out:
# 56

# %%
#locate unmatch data again
olympic_happy2016[olympic_happy2016['Country'].isna()]
# Out:
#     nationality  gold  silver  bronze  total_medals  \
# 3           AND     0       0       0             0
# 5           ANT     0       0       0             0
# 8           ARU     0       0       0             0
# 9           ASA     0       0       0             0
# 13          BAH     1       0       5             6
# 15          BAR     0       0       0             0
# 19          BER     0       0       0             0
# 28          BRU     0       0       0             0
# 31          CAF     0       0       0             0
# 34          CAY     0       0       0             0
# 39          CIV     1       0       1             2
# 42          COK     0       0       0             0
# 45          CPV     0       0       0             0
# 48          CUB     5       2       4            11
# 52          DJI     0       0       0             0
# 53          DMA     0       0       0             0
# 57          ERI     0       0       0             0
# ...

# %%
olympic_happy2016_clean=olympic_happy2016.dropna(subset=['Country'])

# %%
olympic_happy2016_clean['Country'].isna().sum()
# Out:
# 0

# %%
#check data olympic vs happy2017
olympic_happy2017 = pd.merge(olympic, happy_2017, how='left', left_on='country', right_on='Country')

# %%
olympic_happy2017['Country'].isna().sum()
# Out:
# 57

# %%
olympic_happy2017_clean=olympic_happy2017.dropna(subset=['Country'])

# %%
olympic_happy2017_clean['Country'].isna().sum()
# Out:
# 0

# %%
olympic_happy2017_clean[olympic_happy2017_clean['Country'].isna()]
# Out:
# Empty DataFrame
# Columns: [nationality, gold, silver, bronze, total_medals, country, code, population, gdp_per_capita, Country, Happiness_Rank, Happiness_Score, Upper_Confidence_Interval, Lower_Confidence_Interval, Economy_GDP_per_Capita, Family, Health_Life Expectancy, Freedom, Generosity, Trust_Government_Corruption, Dystopia_Residual]
# Index: []

# %%
olympic_happy2017[olympic_happy2017['Country'].isna()]['country']
# Out:
# 3                               Andorra
# 5                   Antigua and Barbuda
# 8                                 Aruba
# 9                        American Samoa
# 13                              Bahamas
# 15                             Barbados
# 19                              Bermuda
# 28                               Brunei
# 34                       Cayman Islands
# 39                        Cote d'Ivoire
# 42                         Cook Islands
# 44                              Comoros
# 45                           Cape Verde
# 48                                 Cuba
# 52                             Djibouti
# 53                             Dominica
# 57                              Eritrea
# 62                                 Fiji
# 65                           Micronesia
# 67                               Gambia
# 69                        Guinea-Bissau
# 71                    Equatorial Guinea
# 75                              Grenada
# ...

# %%
olympic_happy2016[olympic_happy2016['Country'].isna()]['country']
# Out:
# 3                               Andorra
# 5                   Antigua and Barbuda
# 8                                 Aruba
# 9                        American Samoa
# 13                              Bahamas
# 15                             Barbados
# 19                              Bermuda
# 28                               Brunei
# 31             Central African Republic
# 34                       Cayman Islands
# 39                        Cote d'Ivoire
# 42                         Cook Islands
# 45                           Cape Verde
# 48                                 Cuba
# 52                             Djibouti
# 53                             Dominica
# 57                              Eritrea
# 62                                 Fiji
# 65                           Micronesia
# 67                               Gambia
# 69                        Guinea-Bissau
# 71                    Equatorial Guinea
# 75                              Grenada
# ...

# %%
olympic_happy2016_clean.value_sort('total_medals')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-cc528d175475> in <module>
# ----> 1 olympic_happy2016_clean.values_sort('total_medals')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'values_sort'

# %%
happy_compare_clean.head()
# Out:
#        Country          Region  Happiness_Rank_2016  Happiness_Score_2016  \
# 0      Denmark  Western Europe                  1.0                 7.526
# 1  Switzerland  Western Europe                  2.0                 7.509
# 2      Iceland  Western Europe                  3.0                 7.501
# 3       Norway  Western Europe                  4.0                 7.498
# 4      Finland  Western Europe                  5.0                 7.413
#
#    Lower_Confidence_Interval_2016  Upper_Confidence_Interval_2016  \
# 0                           7.460                           7.592
# 1                           7.428                           7.590
# 2                           7.333                           7.669
# 3                           7.421                           7.575
# 4                           7.351                           7.475
#
#    Economy_GDP_per_Capita_2016  Family_2016  Health_Life Expectancy_2016  \
# ...

# %%
happy_compare_clean['diff']=happy_compare_clean['Happiness_Score_2016']-happy_compare_clean['Happiness_Score_2017']

# %%
olympic_corr = pd.merge(olympic, happy_compare_clean, how='left', left_on='country', right_on='Country')

# %%
olympic_corr['Country'].isna().sum()
# Out:
# 53

# %%
olympic_corr_clean=olympic_corr.dropna(subset=['Country'])

# %%
olympic.sort_values(by='total_medals',ascending=False)
# Out:
#     nationality  gold  silver  bronze  total_medals                 country  \
# 198         USA   139      54      71           264           United States
# 72          GER    49      44      67           160                 Germany
# 68          GBR    64      55      26           145          United Kingdom
# 159         RUS    52      29      34           115                  Russia
# 38          CHN    46      30      37           113                   China
# ..          ...   ...     ...     ...           ...                     ...
# 94          IVB     0       0       0             0  British Virgin Islands
# 100         KGZ     0       0       0             0              Kyrgyzstan
# 101         KIR     0       0       0             0                Kiribati
# 1           ALB     0       0       0             0                 Albania
# 206         ZIM     0       0       0             0                Zimbabwe
#
#     code    population  gdp_per_capita
# ...

# %%
plt.scatter(olympic_corr_clean['Happiness_Score_2016'],olympic_corr_clean['total_medals'])

# %%
plt.scatter(olympic_corr_clean['Economy_GDP_per_Capita_2016'],olympic_corr_clean['total_medals'])

# %%
olympic_corr_clean[olympic_corr_clean['country']=='Brazil'][['Economy_GDP_per_Capita_2016','total_medals','Economy_GDP_per_Capita_2017']]
# Out:
#     Economy_GDP_per_Capita_2016  total_medals  Economy_GDP_per_Capita_2017
# 26                      1.08754            51                     1.107353
